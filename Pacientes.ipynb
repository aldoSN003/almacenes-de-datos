# %%
print("hello")
import pandas as pd
# Out:
# hello

# %%
df = pd.read_csv("zona_norte/hospitales.csv")
# Out:
#     HN001                   Hospital General Hermosillo  CTN001
# 0   HN002                 Clínica Pediátrica Hermosillo  CTN001
# 1   HN003              Hospital de Ortopedia Hermosillo  CTN001
# 2   HN004                      Hospital General Nogales  CTN002
# 3   HN005               Clínica de Oftalmología Nogales  CTN002
# 4   HN006                 Hospital de Oncología Nogales  CTN002
# 5   HN007                      Hospital General Caborca  CTN003
# 6   HN008                 Clínica de Neurología Caborca  CTN003
# 7   HN009             Hospital Infantil General Caborca  CTN003
# 8   HN010                      Hospital General Guaymas  CTN004
# 9   HN011              Clínica de Traumatología Guaymas  CTN004
# 10  HN012         Hospital de Gastroenterología Guaymas  CTN004
# 11  HN013                      Hospital General Navojoa  CTN005
# 12  HN014               Clínica de Reumatología Navojoa  CTN005
# 13  HN015                  Hospital de Urología Navojoa  CTN005
# ...

# %%
df.value
